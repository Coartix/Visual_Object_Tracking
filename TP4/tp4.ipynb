# %%
import pandas as pd
import os
import numpy as np
import cv2
from utils import load_detections, track_iou, create_similarity_matrix, associate_detections_to_tracks, update_tracks, draw_tracking_result, save_tracking_results, initialize_new_track
from KalmanFilter import KalmanFilter

# %% [markdown]
# ###  Loading det object instances

# %%
det_file_path = '../data/det/det.txt'
detections_df = load_detections(det_file_path)
detections_df.head()
# Out:
#    frame  id  bb_left  bb_top  bb_width  bb_height    conf  x  y  z
# 0      1  -1     1689     385   146.620    332.710  67.567 -1 -1 -1
# 1      1  -1     1303     503    61.514    139.590  29.439 -1 -1 -1
# 2      1  -1     1258     569    40.123     91.049  19.601 -1 -1 -1
# 3      1  -1       31     525   113.370    257.270  17.013 -1 -1 -1
# 4      1  -1     1800     483    94.660    214.810  11.949 -1 -1 -1

# %% [markdown]
# #### Interface (main loop)

# %%
# Main loop
image_frames_path = '../data/img1/' 

# Define properties for the output video
fps = 40
frame_size = (1920, 1080)  # Adjust this to match the size of your frames
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use 'mp4v' codec
out = cv2.VideoWriter('output_with_tracking.mp4', fourcc, fps, frame_size)
delay = int(1000/fps)

# Initialize tracking variables
tracks = []
frame_number = 1
sigma_iou = 0.2

tracking_file = 'track.txt'
if os.path.isfile(tracking_file):
    open(tracking_file, 'w').close()
else:
    open(tracking_file, 'x')

# Process each image frame
for filename in sorted(os.listdir(image_frames_path)):
    if filename.endswith(".jpg"):
        frame_path = os.path.join(image_frames_path, filename)
        frame = cv2.imread(frame_path)

        # Get current detections for this frame
        current_detections_df = detections_df[detections_df['frame'] == frame_number]
        current_boxes = current_detections_df[['bb_left', 'bb_top', 'bb_width', 'bb_height']].values
        current_confidences = current_detections_df['conf'].values

        # Predict next state for each track using the Kalman Filter
        for track in tracks:
            track['kf'].predict()

        # Compute similarity matrix and associate detections to tracks
        if frame_number > 1:
            similarity_matrix = create_similarity_matrix(current_boxes, tracks) # Similarity matrix between detections and predicted states
            matches, unmatched_detections, unmatched_tracks = associate_detections_to_tracks(similarity_matrix, sigma_iou)
            tracks = update_tracks(matches, unmatched_tracks, unmatched_detections, current_boxes, current_confidences, tracks, frame_number)
        else:
            for i, det in enumerate(current_boxes):
                tracks.append(initialize_new_track(det, current_confidences[i], frame_number))
        
        # Draw tracking
        frame_with_tracking = draw_tracking_result(frame, tracks)
        # Save the tracking results
        save_tracking_results(tracks, tracking_file, frame_number)

        # Show the frame
        cv2.imshow('Tracking', frame_with_tracking)
        if cv2.waitKey(delay) & 0xFF == ord('q'):
            break
        out.write(frame_with_tracking)

        frame_number += 1

out.release()
cv2.destroyAllWindows()
# Out:
# matches: 5, unmatched_detections: 1, unmatched_tracks: 0
# matches: 5, unmatched_detections: 2, unmatched_tracks: 1
# matches: 5, unmatched_detections: 1, unmatched_tracks: 2
# matches: 4, unmatched_detections: 0, unmatched_tracks: 2
# matches: 4, unmatched_detections: 2, unmatched_tracks: 0
# matches: 5, unmatched_detections: 1, unmatched_tracks: 1
# matches: 4, unmatched_detections: 1, unmatched_tracks: 2
# matches: 5, unmatched_detections: 2, unmatched_tracks: 0
# matches: 6, unmatched_detections: 0, unmatched_tracks: 1
# matches: 5, unmatched_detections: 1, unmatched_tracks: 1
# matches: 4, unmatched_detections: 1, unmatched_tracks: 2
# matches: 3, unmatched_detections: 3, unmatched_tracks: 2
# matches: 5, unmatched_detections: 1, unmatched_tracks: 1
# matches: 5, unmatched_detections: 1, unmatched_tracks: 1
# matches: 5, unmatched_detections: 1, unmatched_tracks: 1
# matches: 4, unmatched_detections: 0, unmatched_tracks: 2
# matches: 3, unmatched_detections: 3, unmatched_tracks: 1
# matches: 6, unmatched_detections: 0, unmatched_tracks: 0
# matches: 6, unmatched_detections: 0, unmatched_tracks: 0
# matches: 6, unmatched_detections: 0, unmatched_tracks: 0
# matches: 5, unmatched_detections: 2, unmatched_tracks: 1
# matches: 6, unmatched_detections: 0, unmatched_tracks: 1
# matches: 6, unmatched_detections: 0, unmatched_tracks: 0
# matches: 6, unmatched_detections: 2, unmatched_tracks: 0
# matches: 7, unmatched_detections: 2, unmatched_tracks: 1
# matches: 7, unmatched_detections: 1, unmatched_tracks: 2
# matches: 6, unmatched_detections: 0, unmatched_tracks: 2
# matches: 6, unmatched_detections: 1, unmatched_tracks: 0
# matches: 7, unmatched_detections: 1, unmatched_tracks: 0
# matches: 7, unmatched_detections: 1, unmatched_tracks: 1
# matches: 5, unmatched_detections: 1, unmatched_tracks: 3
# matches: 6, unmatched_detections: 0, unmatched_tracks: 0
# matches: 6, unmatched_detections: 0, unmatched_tracks: 0
# matches: 5, unmatched_detections: 1, unmatched_tracks: 1
# matches: 6, unmatched_detections: 0, unmatched_tracks: 0
# matches: 5, unmatched_detections: 1, unmatched_tracks: 1
# matches: 5, unmatched_detections: 2, unmatched_tracks: 1
# matches: 5, unmatched_detections: 0, unmatched_tracks: 2
# matches: 4, unmatched_detections: 1, unmatched_tracks: 1
# matches: 5, unmatched_detections: 0, unmatched_tracks: 0
# matches: 5, unmatched_detections: 1, unmatched_tracks: 0
# matches: 5, unmatched_detections: 0, unmatched_tracks: 1
# matches: 4, unmatched_detections: 1, unmatched_tracks: 1
# matches: 4, unmatched_detections: 1, unmatched_tracks: 1
# matches: 5, unmatched_detections: 1, unmatched_tracks: 0
# matches: 6, unmatched_detections: 3, unmatched_tracks: 0
# matches: 6, unmatched_detections: 0, unmatched_tracks: 3
# matches: 6, unmatched_detections: 1, unmatched_tracks: 0
# matches: 6, unmatched_detections: 0, unmatched_tracks: 1
# matches: 5, unmatched_detections: 0, unmatched_tracks: 1
# matches: 5, unmatched_detections: 0, unmatched_tracks: 0
# matches: 5, unmatched_detections: 1, unmatched_tracks: 0
# matches: 5, unmatched_detections: 2, unmatched_tracks: 1
# matches: 7, unmatched_detections: 1, unmatched_tracks: 0
# matches: 7, unmatched_detections: 0, unmatched_tracks: 1
# matches: 6, unmatched_detections: 0, unmatched_tracks: 1
# matches: 6, unmatched_detections: 3, unmatched_tracks: 0
# matches: 6, unmatched_detections: 1, unmatched_tracks: 3
# matches: 5, unmatched_detections: 2, unmatched_tracks: 2
# matches: 7, unmatched_detections: 3, unmatched_tracks: 0
# matches: 7, unmatched_detections: 2, unmatched_tracks: 3
# matches: 8, unmatched_detections: 0, unmatched_tracks: 1
# matches: 7, unmatched_detections: 1, unmatched_tracks: 1
# matches: 6, unmatched_detections: 2, unmatched_tracks: 2
# matches: 7, unmatched_detections: 1, unmatched_tracks: 1
# matches: 7, unmatched_detections: 2, unmatched_tracks: 1
# matches: 6, unmatched_detections: 2, unmatched_tracks: 3
# matches: 7, unmatched_detections: 1, unmatched_tracks: 1
# matches: 8, unmatched_detections: 4, unmatched_tracks: 0
# matches: 11, unmatched_detections: 2, unmatched_tracks: 1
# matches: 11, unmatched_detections: 0, unmatched_tracks: 2
# matches: 8, unmatched_detections: 1, unmatched_tracks: 3
# matches: 8, unmatched_detections: 1, unmatched_tracks: 1
# matches: 9, unmatched_detections: 4, unmatched_tracks: 0
# matches: 10, unmatched_detections: 0, unmatched_tracks: 3
# matches: 7, unmatched_detections: 2, unmatched_tracks: 3
# matches: 7, unmatched_detections: 3, unmatched_tracks: 2
# matches: 8, unmatched_detections: 3, unmatched_tracks: 2
# matches: 9, unmatched_detections: 0, unmatched_tracks: 2
# matches: 7, unmatched_detections: 1, unmatched_tracks: 2
# matches: 5, unmatched_detections: 1, unmatched_tracks: 3
# matches: 6, unmatched_detections: 4, unmatched_tracks: 0
# matches: 8, unmatched_detections: 1, unmatched_tracks: 2
# matches: 8, unmatched_detections: 1, unmatched_tracks: 1
# matches: 9, unmatched_detections: 1, unmatched_tracks: 0
# matches: 9, unmatched_detections: 0, unmatched_tracks: 1
# matches: 8, unmatched_detections: 1, unmatched_tracks: 1
# matches: 9, unmatched_detections: 3, unmatched_tracks: 0
# matches: 10, unmatched_detections: 0, unmatched_tracks: 2
# matches: 9, unmatched_detections: 0, unmatched_tracks: 1
# matches: 8, unmatched_detections: 1, unmatched_tracks: 1
# matches: 8, unmatched_detections: 1, unmatched_tracks: 1
# matches: 8, unmatched_detections: 2, unmatched_tracks: 1
# matches: 7, unmatched_detections: 0, unmatched_tracks: 3
# matches: 5, unmatched_detections: 2, unmatched_tracks: 2
# matches: 6, unmatched_detections: 2, unmatched_tracks: 1
# matches: 4, unmatched_detections: 2, unmatched_tracks: 4
# matches: 6, unmatched_detections: 3, unmatched_tracks: 0
# matches: 7, unmatched_detections: 1, unmatched_tracks: 2
# matches: 6, unmatched_detections: 0, unmatched_tracks: 2
# matches: 6, unmatched_detections: 2, unmatched_tracks: 0
# matches: 6, unmatched_detections: 1, unmatched_tracks: 2
# matches: 7, unmatched_detections: 0, unmatched_tracks: 0
# matches: 6, unmatched_detections: 0, unmatched_tracks: 1
# matches: 6, unmatched_detections: 1, unmatched_tracks: 0
# matches: 7, unmatched_detections: 3, unmatched_tracks: 0
# matches: 6, unmatched_detections: 0, unmatched_tracks: 4
# matches: 6, unmatched_detections: 1, unmatched_tracks: 0
# matches: 5, unmatched_detections: 0, unmatched_tracks: 2
# matches: 5, unmatched_detections: 3, unmatched_tracks: 0
# matches: 7, unmatched_detections: 0, unmatched_tracks: 1
# matches: 6, unmatched_detections: 1, unmatched_tracks: 1
# matches: 3, unmatched_detections: 1, unmatched_tracks: 4
# matches: 3, unmatched_detections: 3, unmatched_tracks: 1
# matches: 4, unmatched_detections: 2, unmatched_tracks: 2
# matches: 4, unmatched_detections: 1, unmatched_tracks: 2
# matches: 4, unmatched_detections: 3, unmatched_tracks: 1
# matches: 4, unmatched_detections: 2, unmatched_tracks: 3
# matches: 6, unmatched_detections: 4, unmatched_tracks: 0
# matches: 9, unmatched_detections: 0, unmatched_tracks: 1
# matches: 8, unmatched_detections: 2, unmatched_tracks: 1
# matches: 8, unmatched_detections: 1, unmatched_tracks: 2
# matches: 8, unmatched_detections: 2, unmatched_tracks: 1
# matches: 8, unmatched_detections: 2, unmatched_tracks: 2
# matches: 8, unmatched_detections: 3, unmatched_tracks: 2
# matches: 8, unmatched_detections: 0, unmatched_tracks: 3
# matches: 7, unmatched_detections: 1, unmatched_tracks: 1
# matches: 7, unmatched_detections: 2, unmatched_tracks: 1
# matches: 5, unmatched_detections: 1, unmatched_tracks: 4
# matches: 6, unmatched_detections: 2, unmatched_tracks: 0
# matches: 6, unmatched_detections: 2, unmatched_tracks: 2
# matches: 5, unmatched_detections: 2, unmatched_tracks: 3
# matches: 6, unmatched_detections: 0, unmatched_tracks: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 29
#      26 frame = cv2.imread(frame_path)
#      28 # Get current detections for this frame
# ---> 29 current_detections_df = detections_df[detections_df['frame'] == frame_number]
#      30 current_boxes = current_detections_df[['bb_left', 'bb_top', 'bb_width', 'bb_height']].values
#      31 current_confidences = current_detections_df['conf'].values
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:3798, in DataFrame.__getitem__(self, key)
#    3796 # Do we have a (boolean) 1d indexer?
#    3797 if com.is_bool_indexer(key):
# -> 3798     return self._getitem_bool_array(key)
#    3800 # We are left with two options: a single key, and a collection of keys,
#    3801 # We interpret tuples as collections only for non-MultiIndex
#    3802 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:3853, in DataFrame._getitem_bool_array(self, key)
#    3851 key = check_bool_indexer(self.index, key)
#    3852 indexer = key.nonzero()[0]
# -> 3853 return self._take_with_is_copy(indexer, axis=0)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py:3902, in NDFrame._take_with_is_copy(self, indices, axis)
#    3894 def _take_with_is_copy(self: NDFrameT, indices, axis=0) -> NDFrameT:
#    3895     """
#    3896     Internal version of the `take` method that sets the `_is_copy`
#    3897     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3900     See the docstring of `take` for full explanation of the parameters.
#    3901     """
# -> 3902     result = self._take(indices=indices, axis=axis)
#    3903     # Maybe set copy if we didn't actually change the index.
#    3904     if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py:3886, in NDFrame._take(self, indices, axis, convert_indices)
#    3879 """
#    3880 Internal version of the `take` allowing specification of additional args.
#    3881
#    3882 See the docstring of `take` for full explanation of the parameters.
#    3883 """
#    3884 self._consolidate_inplace()
# -> 3886 new_data = self._mgr.take(
#    3887     indices,
#    3888     axis=self._get_block_manager_axis(axis),
#    3889     verify=True,
#    3890     convert_indices=convert_indices,
#    3891 )
#    3892 return self._constructor(new_data).__finalize__(self, method="take")
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py:978, in BaseBlockManager.take(self, indexer, axis, verify, convert_indices)
#     975     indexer = maybe_convert_indices(indexer, n, verify=verify)
#     977 new_labels = self.axes[axis].take(indexer)
# --> 978 return self.reindex_indexer(
#     979     new_axis=new_labels,
#     980     indexer=indexer,
#     981     axis=axis,
#     982     allow_dups=True,
#     983     copy=None,
#     984 )
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py:751, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     749     parent = None if com.all_none(*new_refs) else self
#     750 else:
# --> 751     new_blocks = [
#     752         blk.take_nd(
#     753             indexer,
#     754             axis=1,
#     755             fill_value=(
#     756                 fill_value if fill_value is not None else blk.fill_value
#     757             ),
#     758         )
#     759         for blk in self.blocks
#     760     ]
#     761     new_refs = None
#     762     parent = None
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py:752, in <listcomp>(.0)
#     749     parent = None if com.all_none(*new_refs) else self
#     750 else:
#     751     new_blocks = [
# --> 752         blk.take_nd(
#     753             indexer,
#     754             axis=1,
#     755             fill_value=(
#     756                 fill_value if fill_value is not None else blk.fill_value
#     757             ),
#     758         )
#     759         for blk in self.blocks
#     760     ]
#     761     new_refs = None
#     762     parent = None
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py:880, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#     877     allow_fill = True
#     879 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# --> 880 new_values = algos.take_nd(
#     881     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#     882 )
#     884 # Called from three places in managers, all of which satisfy
#     885 #  this assertion
#     886 assert not (axis == 0 and new_mgr_locs is None)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/array_algos/take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/array_algos/take.py:160, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     157 else:
#     158     out = np.empty(out_shape, dtype=dtype)
# --> 160 func = _get_take_nd_function(
#     161     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162 )
#     163 func(arr, indexer, out, fill_value)
#     165 if flip_order:
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/array_algos/take.py:326, in _get_take_nd_function(ndim, arr_dtype, out_dtype, axis, mask_info)
#     321         return func
#     323     return None
# --> 326 def _get_take_nd_function(
#     327     ndim: int, arr_dtype: np.dtype, out_dtype: np.dtype, axis: int = 0, mask_info=None
#     328 ):
#     329     """
#     330     Get the appropriate "take" implementation for the given dimension, axis
#     331     and dtypes.
#     332     """
#     333     func = None
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
